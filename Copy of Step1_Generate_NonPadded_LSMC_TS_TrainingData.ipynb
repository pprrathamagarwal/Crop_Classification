# %% [markdown]
# # Set Coding Environment

# %% [markdown]
# ## Library installations

# %%
# !pip install geemap geopandas
# Out:
# Requirement already satisfied: geemap in c:\users\prath\anaconda3\lib\site-packages (0.34.0)
# Requirement already satisfied: geopandas in c:\users\prath\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: bqplot in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.12.43)
# Requirement already satisfied: colour in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.1.401)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.16.0)
# Requirement already satisfied: geocoder in c:\users\prath\anaconda3\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\prath\anaconda3\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.19.0)
# Requirement already satisfied: ipytree in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\prath\anaconda3\lib\site-packages (from geemap) (3.8.0)
# Requirement already satisfied: numpy in c:\users\prath\anaconda3\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\prath\anaconda3\lib\site-packages (from geemap) (2.1.4)
# Requirement already satisfied: plotly in c:\users\prath\anaconda3\lib\site-packages (from geemap) (5.9.0)
# Requirement already satisfied: pyperclip in c:\users\prath\anaconda3\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\prath\anaconda3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\prath\anaconda3\lib\site-packages (from geemap) (7.2.0)
# Requirement already satisfied: scooby in c:\users\prath\anaconda3\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\prath\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in c:\users\prath\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\prath\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\prath\anaconda3\lib\site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: google-cloud-storage in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.16.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.127.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.29.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\prath\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.27.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.8.30)
# Requirement already satisfied: click~=8.0 in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\prath\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\prath\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\prath\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (3.1.3)
# Requirement already satisfied: xyzservices in c:\users\prath\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (2022.9.0)
# Requirement already satisfied: ipywidgets in c:\users\prath\anaconda3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.6.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\prath\anaconda3\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.19.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\prath\anaconda3\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\anaconda3\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prath\anaconda3\lib\site-packages (from pandas->geemap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\prath\anaconda3\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\prath\anaconda3\lib\site-packages (from bqplot->geemap) (5.7.1)
# Requirement already satisfied: future in c:\users\prath\anaconda3\lib\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\prath\anaconda3\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prath\anaconda3\lib\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prath\anaconda3\lib\site-packages (from plotly->geemap) (8.2.2)
# Requirement already satisfied: colorama in c:\users\prath\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\prath\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (2.19.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\prath\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prath\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prath\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prath\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\prath\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prath\anaconda3\lib\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.3)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\prath\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\prath\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\prath\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prath\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (1.26.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\prath\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prath\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.4)
# Requirement already satisfied: decorator in c:\users\prath\anaconda3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\prath\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\prath\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\prath\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.23.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.0)
# Requirement already satisfied: psutil in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\prath\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\prath\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\prath\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\prath\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\prath\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.19.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\prath\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.4.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\prath\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\prath\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.10.6)
# Requirement already satisfied: entrypoints in c:\users\prath\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (305.1)
# Requirement already satisfied: argon2-cffi in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.10.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\prath\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.0.0)
# Requirement already satisfied: wcwidth in c:\users\prath\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\prath\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\prath\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.10.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\users\prath\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\prath\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\prath\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\prath\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\prath\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.4)
# Requirement already satisfied: overrides in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.0)
# Requirement already satisfied: websocket-client in c:\users\prath\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\prath\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\prath\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prath\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\prath\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\prath\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.1)
# Requirement already satisfied: uri-template in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\prath\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\prath\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.3)
# DEPRECATION: Loading egg at c:\users\prath\anaconda3\lib\site-packages\agoro_field_boundary_detector-0.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Module Imports

# %%
import geemap
import geopandas as gpd
from pprint import pprint
import ee
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/LULC_Experiments_Chahat_Ananjan_Saketh
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /content/drive/MyDrive/LULC_Experiments_Chahat_Ananjan_Saketh

# %% [markdown]
# ## Authenticate to Google Earth Engine

# %%
ee.Authenticate() #Uncomment this whenever needed, once done usually not needed for 1-2 days
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize(project='proj76')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Function Definitions

# %% [markdown]
# ## Defining constants

# %%
chastainBandNames = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']

# Regression model parameters from Table-4. MSI TOA reflectance as a function of OLI TOA reflectance.
msiOLISlopes = [1.0946,1.0043,1.0524,0.8954,1.0049,1.0002]
msiOLIIntercepts = [-0.0107,0.0026,-0.0015,0.0033,0.0065,0.0046]

# Regression model parameters from Table-5. MSI TOA reflectance as a function of ETM+ TOA reflectance.
msiETMSlopes = [1.10601,0.99091,1.05681,1.0045,1.03611,1.04011]
msiETMIntercepts = [-0.0139,0.00411,-0.0024,-0.0076,0.00411,0.00861]

# Regression model parameters from Table-6. OLI TOA reflectance as a function of ETM+ TOA reflectance.
oliETMSlopes =[1.03501,1.00921,1.01991,1.14061,1.04351,1.05271];
oliETMIntercepts = [-0.0055,-0.0008,-0.0021,-0.0163,-0.0045,0.00261]

# Construct dictionary to handle all pairwise combos
chastainCoeffDict = { 'MSI_OLI':[msiOLISlopes,msiOLIIntercepts,1], # check what the third item corresponds to
                      'MSI_ETM':[msiETMSlopes,msiETMIntercepts,1],
                      'OLI_ETM':[oliETMSlopes,oliETMIntercepts,1],
                      'OLI_MSI':[msiOLISlopes,msiOLIIntercepts,0],
                      'ETM_MSI':[msiETMSlopes,msiETMIntercepts,0],
                      'ETM_OLI':[oliETMSlopes,oliETMIntercepts,0]
                    }
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Function defnitions

# %%
'''
Function to mask cloudy pixels in Landsat-7
'''
'''
Function to mask cloudy pixels in Landsat-7
'''
def maskl8cloud(image):
    qa = image.select('QA_PIXEL')
    cloud_mask = qa.bitwiseAnd(1 << 4).eq(0).And(qa.bitwiseAnd(1 << 5).eq(0))
    return image.updateMask(cloud_mask).select(
        ['B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    ).rename(['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2'])

def maskl7cloud(image):
    qa = image.select('QA_PIXEL')
    cloud_mask = qa.bitwiseAnd(1 << 4).eq(0).And(qa.bitwiseAnd(1 << 5).eq(0))
    return image.updateMask(cloud_mask).select(
        ['B1', 'B2', 'B3', 'B4', 'B5', 'B7']
    ).rename(['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2'])

def masks2cloud(image):
    cloud_prob = image.select('MSK_CLDPRB')
    mask = cloud_prob.lt(20)  # Cloud probability < 20%
    return image.select(
        ['B2', 'B3', 'B4', 'B8', 'B11', 'B12']
    ).rename(['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']).updateMask(mask)

'''
Sensor Harmonization Configuration (Updated for TOA)
'''
# Band names matching TOA collections
chastainBandNames = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']

'''
Get Landsat and Sentinel image collections
'''
def Get_L7_L8_S2_ImageCollections(inputStartDate, inputEndDate, roi_boundary):
  # ------ Landsat 7 TOA
  L7 = ee.ImageCollection('LANDSAT/LE07/C02/T1_TOA') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary) \
          .map(maskl7cloud)
  # print('\n Original Landsat 7 TOA dataset: \n',L7.limit(1).getInfo())
  # print('Number of images in Landsat 7 TOA dataset: \t',L7.size().getInfo())

  # ------ Landsat 8 TOA
  L8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary) \
          .map(maskl8cloud)
  # print('\n Original Landsat 8 TOA dataset: \n', L8.limit(1).getInfo())
  # print('Number of images in Landsat 8 TOA dataset: \t',L8.size().getInfo())

  # ------ Sentinel-2 TOA
  S2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary)  \
          .map(masks2cloud)
  # print('\n Original Sentinel-2 TOA dataset: \n',S2.limit(1).getInfo())
  # print('Number of images in Sentinel 2 TOA dataset: \t',S2.size().getInfo())

  return L7, L8, S2


'''
Function to apply model in one direction
'''
def dir0Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).multiply(slopes).add(intercepts)


'''
Applying the model in the opposite direction
'''
def dir1Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).subtract(intercepts).divide(slopes)


'''
Function to correct one sensor to another
'''
def harmonizationChastain(img, fromSensor,toSensor):
  # Get the model for the given from and to sensor
  comboKey = fromSensor.upper() + '_' + toSensor.upper()
  coeffList = chastainCoeffDict[comboKey]
  slopes = coeffList[0]
  intercepts = coeffList[1]
  direction = ee.Number(coeffList[2])

  # Apply the model in the respective direction
  out = ee.Algorithms.If(direction.eq(0),dir0Regression(img,slopes,intercepts),dir1Regression(img,slopes,intercepts))
  return ee.Image(out).copyProperties(img).copyProperties(img,['system:time_start'])


'''
Calibrate Landsat-8 (OLI) and Sentinel-2 (MSI) to Landsat-7 (ETM+)
'''
def Harmonize_L7_L8_S2(L7, L8, S2):
  # harmonization
  harmonized_L8 = L8.map( lambda img: harmonizationChastain(img, 'OLI','ETM') )
  harmonized_S2 = S2.map( lambda img: harmonizationChastain(img, 'MSI','ETM') )

  # Merge harmonized landsat-8 and sentinel-2 to landsat-7 image collection
  harmonized_LandsatSentinel_ic = ee.ImageCollection(L7.merge(harmonized_L8).merge(harmonized_S2))
  # print(harmonized_LandsatSentinel_ic.size().getInfo())
  return harmonized_LandsatSentinel_ic


'''
Add NDVI band to harmonized image collection
'''
def addNDVI(image):
  return image.addBands(image.normalizedDifference(['NIR', 'RED']).rename('NDVI')).float()


'''
Function definitions to get NDVI values at each 16-day composites
'''
def Get_NDVI_image_datewise(harmonized_LS_ic):
  def get_NDVI_datewise(date):
    return harmonized_LS_ic.select(['NDVI']) \
                            .filterDate(ee.Date(date), ee.Date(date).advance(16, 'day')) \
                            .median() \
                            .set('system:time_start',ee.Date(date).millis())
  return get_NDVI_datewise

def Get_LS_16Day_NDVI_TimeSeries(inputStartDate, inputEndDate, harmonized_LS_ic):
  startDate = datetime.strptime(inputStartDate,"%Y-%m-%d")
  endDate = datetime.strptime(inputEndDate,"%Y-%m-%d")

  date_list = pd.date_range(start=startDate, end=endDate, freq='5D').tolist()
  date_list = ee.List( [datetime.strftime(curr_date,"%Y-%m-%d") for curr_date in date_list] )

  LSC =  ee.ImageCollection.fromImages(date_list.map(Get_NDVI_image_datewise(harmonized_LS_ic)))

  return LSC


'''
Pair available LSC and modis values for each time stamp.
'''
def pairLSModis(lsRenameBands):
  def pair(feature):
    date = ee.Date( feature.get('system:time_start') )
    startDateT = date.advance(-8,'day')
    endDateT = date.advance(8,'day')

    # ------ MODIS VI ( We can add EVI to the band list later )
    modis = ee.ImageCollection('MODIS/061/MOD13Q1') \
              .filterDate(startDateT, endDateT) \
              .select(['NDVI','SummaryQA']) \
              .filterBounds(roi_boundary) \
              .median() \
              .rename(['NDVI_modis', 'SummaryQA_modis'])

    return feature.rename(lsRenameBands).addBands(modis)
  return pair


'''
Function to get Pearson Correlation Coffecient to perform GapFilling
'''
def get_Pearson_Correlation_Coefficients(LSC_modis_paired_ic, roi_boundary, bandList):
  corr = LSC_modis_paired_ic.filterBounds(roi_boundary) \
                            .select(bandList).toArray() \
                            .arrayReduce( reducer = ee.Reducer.pearsonsCorrelation(), axes=[0], fieldAxis=1 ) \
                            .arrayProject([1]).arrayFlatten([['c', 'p']])
  return corr


'''
Fill gaps in LSC timeseries using modis data
'''
def gapfillLSM(LSC_modis_regression_model, LSC_bandName, modis_bandName):
  def peformGapfilling(image):
    offset = LSC_modis_regression_model.select('offset')
    scale = LSC_modis_regression_model.select('scale')
    nodata = -1

    lsc_image = image.select(LSC_bandName)
    modisfit = image.select(modis_bandName).multiply(scale).add(offset)

    mask = lsc_image.mask()#update mask needs an input (no default input from the API document)
    gapfill = lsc_image.unmask(nodata)
    gapfill = gapfill.where(mask.Not(), modisfit)

    '''
    in SummaryQA,
    0: Good data, use with confidence
    1: Marginal data, useful but look at detailed QA for more information
    2: Pixel covered with snow/ice
    3: Pixel is cloudy
    '''
    qc_m = image.select('SummaryQA_modis').unmask(3)  # missing value is grouped as cloud
    w_m  = modisfit.mask().rename('w_m').where(qc_m.eq(0), 0.8)  # default is 0.8
    w_m = w_m.where(qc_m.eq(1), 0.5)   # Marginal
    w_m = w_m.where(qc_m.gte(2), 0.2) # snow/ice or cloudy

    # make sure these modis values are read where there is missing data from LandSat, Sentinel
    w_l = gapfill.mask() # default is 1
    w_l = w_l.where(mask.Not(), w_m)

    return gapfill.addBands(w_l).rename(['gapfilled_'+LSC_bandName,'SummaryQA']) #have NDVI from modis and a summary of clarity for each

  return peformGapfilling


'''
Function to combine LSC with Modis data
'''
def Combine_LS_Modis(LSC):
  lsRenameBands = ee.Image(LSC.first()).bandNames().map( lambda band: ee.String(band).cat('_lsc') )
  LSC_modis_paired_ic = LSC.map( pairLSModis(lsRenameBands) )

  # Output contains scale, offset i.e. two bands
  LSC_modis_regression_model_NDVI = LSC_modis_paired_ic.select(['NDVI_modis', 'NDVI_lsc']) \
                                                        .reduce(ee.Reducer.linearFit())

  corr_NDVI = get_Pearson_Correlation_Coefficients(LSC_modis_paired_ic, roi_boundary, ['NDVI_modis', 'NDVI_lsc'])
  LSMC_NDVI = LSC_modis_paired_ic.map(gapfillLSM(LSC_modis_regression_model_NDVI, 'NDVI_lsc', 'NDVI_modis'))

  return LSMC_NDVI


'''
Mask out low quality pixels
'''
def mask_low_QA(lsmc_image):
  low_qa = lsmc_image.select('SummaryQA').neq(0.2)
  return lsmc_image.updateMask(low_qa).copyProperties(lsmc_image, ['system:time_start'])


'''
Add image timestamp to each image in time series
'''
def add_timestamp(image):
  timeImage = image.metadata('system:time_start').rename('timestamp')
  timeImageMasked = timeImage.updateMask(image.mask().select(0))
  return image.addBands(timeImageMasked)


'''
Perform linear interpolation on missing values
'''
def performInterpolation(image):
  image = ee.Image(image)
  beforeImages = ee.List(image.get('before'))
  beforeMosaic = ee.ImageCollection.fromImages(beforeImages).mosaic()
  afterImages = ee.List(image.get('after'))
  afterMosaic = ee.ImageCollection.fromImages(afterImages).mosaic()

  # Interpolation formula
  # y = y1 + (y2-y1)*((t – t1) / (t2 – t1))
  # y = interpolated image
  # y1 = before image
  # y2 = after image
  # t = interpolation timestamp
  # t1 = before image timestamp
  # t2 = after image timestamp

  t1 = beforeMosaic.select('timestamp').rename('t1')
  t2 = afterMosaic.select('timestamp').rename('t2')
  t = image.metadata('system:time_start').rename('t')
  timeImage = ee.Image.cat([t1, t2, t])
  timeRatio = timeImage.expression('(t - t1) / (t2 - t1)', {
                  't': timeImage.select('t'),
                  't1': timeImage.select('t1'),
                  't2': timeImage.select('t2'),
              })

  interpolated = beforeMosaic.add((afterMosaic.subtract(beforeMosaic).multiply(timeRatio)))
  result = image.unmask(interpolated)
  fill_value = ee.ImageCollection([beforeMosaic, afterMosaic]).mosaic()
  result = result.unmask(fill_value)

  return result.copyProperties(image, ['system:time_start'])


def interpolate_timeseries(S1_TS):
  lsmc_masked = S1_TS.map(mask_low_QA)
  filtered = lsmc_masked.map(add_timestamp)

  # Time window in which we are willing to look forward and backward for unmasked pixel in time series
  timeWindow = 120

  # Define a maxDifference filter to find all images within the specified days. Convert days to milliseconds.
  millis = ee.Number(timeWindow).multiply(1000*60*60*24)
  # Filter says that pick only those timestamps which lie between the 2 timestamps not more than millis difference apart
  maxDiffFilter = ee.Filter.maxDifference(
                              difference = millis,
                              leftField = 'system:time_start',
                              rightField = 'system:time_start',
                            )

  # Filter to find all images after a given image. Compare the image's timstamp against other images.
  # Images ahead of target image should have higher timestamp.
  lessEqFilter = ee.Filter.lessThanOrEquals(
                            leftField = 'system:time_start',
                            rightField = 'system:time_start'
                          )

  # Similarly define this filter to find all images before a given image
  greaterEqFilter = ee.Filter.greaterThanOrEquals(
                            leftField = 'system:time_start',
                            rightField = 'system:time_start'
                          )

  # Apply first join to find all images that are after the target image but within the timeWindow
  filter1 = ee.Filter.And( maxDiffFilter, lessEqFilter )
  join1 = ee.Join.saveAll(
                  matchesKey = 'after',
                  ordering = 'system:time_start',
                  ascending = False
          )
  join1Result = join1.apply(
                  primary = filtered,
                  secondary = filtered,
                  condition = filter1
                )

  # Apply first join to find all images that are after the target image but within the timeWindow
  filter2 = ee.Filter.And( maxDiffFilter, greaterEqFilter )
  join2 = ee.Join.saveAll(
                  matchesKey = 'before',
                  ordering = 'system:time_start',
                  ascending = True
          )
  join2Result = join2.apply(
                  primary = join1Result,
                  secondary = join1Result,
                  condition = filter2
                )

  interpolated_S1_TS = ee.ImageCollection(join2Result.map(performInterpolation))

  return interpolated_S1_TS
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
chastainBandNames = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']

# Regression model parameters from Table-4. MSI TOA reflectance as a function of OLI TOA reflectance.
msiOLISlopes = [1.0946,1.0043,1.0524,0.8954,1.0049,1.0002]
msiOLIIntercepts = [-0.0107,0.0026,-0.0015,0.0033,0.0065,0.0046]

# Regression model parameters from Table-5. MSI TOA reflectance as a function of ETM+ TOA reflectance.
msiETMSlopes = [1.10601,0.99091,1.05681,1.0045,1.03611,1.04011]
msiETMIntercepts = [-0.0139,0.00411,-0.0024,-0.0076,0.00411,0.00861]

# Regression model parameters from Table-6. OLI TOA reflectance as a function of ETM+ TOA reflectance.
oliETMSlopes =[1.03501,1.00921,1.01991,1.14061,1.04351,1.05271];
oliETMIntercepts = [-0.0055,-0.0008,-0.0021,-0.0163,-0.0045,0.00261]

# Construct dictionary to handle all pairwise combos
chastainCoeffDict = { 'MSI_OLI':[msiOLISlopes,msiOLIIntercepts,1], # check what the third item corresponds to
                      'MSI_ETM':[msiETMSlopes,msiETMIntercepts,1],
                      'OLI_ETM':[oliETMSlopes,oliETMIntercepts,1],
                      'OLI_MSI':[msiOLISlopes,msiOLIIntercepts,0],
                      'ETM_MSI':[msiETMSlopes,msiETMIntercepts,0],
                      'ETM_OLI':[oliETMSlopes,oliETMIntercepts,0]
                    }


'''
Function to mask cloudy pixels in Landsat-7
'''
def maskL7cloud(image):
  qa = image.select('QA_PIXEL')
  mask = qa.bitwiseAnd(1 << 4).eq(0)
  return image.updateMask(mask).select(['B1', 'B2', 'B3' , 'B4' , 'B5' , 'B7']).rename('BLUE', 'GREEN', 'RED' , 'NIR' , 'SWIR1' , 'SWIR2')


'''
Function to mask cloudy pixels in Landsat-8
'''
def maskL8cloud(image):
  qa = image.select('QA_PIXEL')
  mask = qa.bitwiseAnd(1 << 4).eq(0)
  return image.updateMask(mask).select(['B2', 'B3', 'B4' , 'B5' , 'B6' , 'B7']).rename('BLUE', 'GREEN', 'RED' , 'NIR' , 'SWIR1' , 'SWIR2')


'''
Function to mask clouds using the quality band of Sentinel-2 TOA
'''
def maskS2cloudTOA(image):
  qa = image.select('QA60')
  # Bits 10 and 11 are clouds and cirrus, respectively.
  cloudBitMask = 1 << 10
  cirrusBitMask = 1 << 11
  # Both flags should be set to zero, indicating clear conditions.
  mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0));
  return image.updateMask(mask).select(['B2', 'B3', 'B4', 'B8',  'B11', 'B12']).rename(['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2'])


'''
Get Landsat and Sentinel image collections
'''
def Get_L7_L8_S2_ImageCollections(inputStartDate, inputEndDate, roi_boundary):
  # ------ Landsat 7 TOA
  L7 = ee.ImageCollection('LANDSAT/LE07/C02/T1_TOA') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary) \
          .map(maskL7cloud)
  # print('\n Original Landsat 7 TOA dataset: \n',L7.limit(1).getInfo())
  # print('Number of images in Landsat 7 TOA dataset: \t',L7.size().getInfo())

  # ------ Landsat 8 TOA
  L8 = ee.ImageCollection('LANDSAT/LC08/C02/T1_TOA') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary) \
          .map(maskL8cloud)
  # print('\n Original Landsat 8 TOA dataset: \n', L8.limit(1).getInfo())
  # print('Number of images in Landsat 8 TOA dataset: \t',L8.size().getInfo())

  # ------ Sentinel-2 TOA
  S2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED') \
          .filterDate(inputStartDate, inputEndDate) \
          .filterBounds(roi_boundary)  \
          .map(maskS2cloudTOA)
  # print('\n Original Sentinel-2 TOA dataset: \n',S2.limit(1).getInfo())
  # print('Number of images in Sentinel 2 TOA dataset: \t',S2.size().getInfo())

  return L7, L8, S2


'''
Function to apply model in one direction
'''
def dir0Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).multiply(slopes).add(intercepts)


'''
Applying the model in the opposite direction
'''
def dir1Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).subtract(intercepts).divide(slopes)


'''
Function to apply model in one direction
'''
def dir0Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).multiply(slopes).add(intercepts)


'''
Applying the model in the opposite direction
'''
def dir1Regression(img,slopes,intercepts):
  return img.select(chastainBandNames).subtract(intercepts).divide(slopes)


'''
Function to correct one sensor to another
'''
def harmonizationChastain(img, fromSensor,toSensor):
  # Get the model for the given from and to sensor
  comboKey = fromSensor.upper() + '_' + toSensor.upper()
  coeffList = chastainCoeffDict[comboKey]
  slopes = coeffList[0]
  intercepts = coeffList[1]
  direction = ee.Number(coeffList[2])

  # Apply the model in the respective direction
  out = ee.Algorithms.If(direction.eq(0),dir0Regression(img,slopes,intercepts),dir1Regression(img,slopes,intercepts))
  return ee.Image(out).copyProperties(img).copyProperties(img,['system:time_start'])


'''
Calibrate Landsat-8 (OLI) and Sentinel-2 (MSI) to Landsat-7 (ETM+)
'''
def Harmonize_L7_L8_S2(L7, L8, S2):
  # harmonization
  harmonized_L8 = L8.map( lambda img: harmonizationChastain(img, 'OLI','ETM') )
  harmonized_S2 = S2.map( lambda img: harmonizationChastain(img, 'MSI','ETM') )

  # Merge harmonized landsat-8 and sentinel-2 to landsat-7 image collection
  harmonized_LandsatSentinel_ic = ee.ImageCollection(L7.merge(harmonized_L8).merge(harmonized_S2))
  # print(harmonized_LandsatSentinel_ic.size().getInfo())
  return harmonized_LandsatSentinel_ic




def addNDVI(image):
    gcvi = image.select('NIR').divide(image.select('GREEN')).subtract(1).rename('NDVI')
    return image.addBands(gcvi).float()



'''
Function definitions to get NDVI values at each 16-day composites
'''
def Get_NDVI_image_datewise(harmonized_LS_ic):
  def get_NDVI_datewise(date):
    return harmonized_LS_ic.select(['NDVI']) \
                            .filterDate(ee.Date(date), ee.Date(date).advance(16, 'day')) \
                            .median() \
                            .set('system:time_start',ee.Date(date).millis())
  return get_NDVI_datewise

def Get_LS_16Day_NDVI_TimeSeries(inputStartDate, inputEndDate, harmonized_LS_ic):
  startDate = datetime.strptime(inputStartDate,"%Y-%m-%d")
  endDate = datetime.strptime(inputEndDate,"%Y-%m-%d")

  date_list = pd.date_range(start=startDate, end=endDate, freq='16D').tolist()
  date_list = ee.List( [datetime.strftime(curr_date,"%Y-%m-%d") for curr_date in date_list] )

  LSC =  ee.ImageCollection.fromImages(date_list.map(Get_NDVI_image_datewise(harmonized_LS_ic)))

  return LSC


'''
Pair available LSC and modis values for each time stamp.
'''
def pairLSModis(lsRenameBands):
  def pair(feature):
    date = ee.Date( feature.get('system:time_start') )
    startDateT = date.advance(-8,'day')
    endDateT = date.advance(8,'day')

    # ------ MODIS VI ( We can add EVI to the band list later )
    modis = ee.ImageCollection('MODIS/061/MOD13Q1') \
              .filterDate(startDateT, endDateT) \
              .select(['NDVI','SummaryQA']) \
              .filterBounds(roi_boundary) \
              .median() \
              .rename(['NDVI_modis', 'SummaryQA_modis'])

    return feature.rename(lsRenameBands).addBands(modis)
  return pair


'''
Function to get Pearson Correlation Coffecient to perform GapFilling
'''
def get_Pearson_Correlation_Coefficients(LSC_modis_paired_ic, roi_boundary, bandList):
  corr = LSC_modis_paired_ic.filterBounds(roi_boundary) \
                            .select(bandList).toArray() \
                            .arrayReduce( reducer = ee.Reducer.pearsonsCorrelation(), axes=[0], fieldAxis=1 ) \
                            .arrayProject([1]).arrayFlatten([['c', 'p']])
  return corr



'''Use print(...) to write to this console.
Fill gaps in LSC timeseries using modis data
'''
def gapfillLSM(LSC_modis_regression_model, LSC_bandName, modis_bandName):
  def peformGapfilling(image):
    offset = LSC_modis_regression_model.select('offset')
    scale = LSC_modis_regression_model.select('scale')
    nodata = -1

    lsc_image = image.select(LSC_bandName)
    modisfit = image.select(modis_bandName).multiply(scale).add(offset)

    mask = lsc_image.mask()#update mask needs an input (no default input from the API document)
    gapfill = lsc_image.unmask(nodata)
    gapfill = gapfill.where(mask.Not(), modisfit)

    '''
    in SummaryQA,
    0: Good data, use with confidence
    1: Marginal data, useful but look at detailed QA for more information
    2: Pixel covered with snow/ice
    3: Pixel is cloudy
    '''
    qc_m = image.select('SummaryQA_modis').unmask(3)  # missing value is grouped as cloud
    w_m  = modisfit.mask().rename('w_m').where(qc_m.eq(0), 0.8)  # default is 0.8
    w_m = w_m.where(qc_m.eq(1), 0.5)   # Marginal
    w_m = w_m.where(qc_m.gte(2), 0.2) # snow/ice or cloudy

    # make sure these modis values are read where there is missing data from LandSat, Sentinel
    w_l = gapfill.mask() # default is 1
    w_l = w_l.where(mask.Not(), w_m)

    return gapfill.addBands(w_l).rename(['gapfilled_'+LSC_bandName,'SummaryQA']) #have NDVI from modis and a summary of clarity for each

  return peformGapfilling


'''
Function to combine LSC with Modis data
'''
def Combine_LS_Modis(LSC):
  lsRenameBands = ee.Image(LSC.first()).bandNames().map( lambda band: ee.String(band).cat('_lsc') )
  LSC_modis_paired_ic = LSC.map( pairLSModis(lsRenameBands) )

  # Output contains scale, offset i.e. two bands
  LSC_modis_regression_model_NDVI = LSC_modis_paired_ic.select(['NDVI_modis', 'NDVI_lsc']) \
                                                        .reduce(ee.Reducer.linearFit())

  corr_NDVI = get_Pearson_Correlation_Coefficients(LSC_modis_paired_ic, roi_boundary, ['NDVI_modis', 'NDVI_lsc'])
  LSMC_NDVI = LSC_modis_paired_ic.map(gapfillLSM(LSC_modis_regression_model_NDVI, 'NDVI_lsc', 'NDVI_modis'))

  return LSMC_NDVI


'''
Mask out low quality pixels
'''
def mask_low_QA(lsmc_image):
  low_qa = lsmc_image.select('SummaryQA').neq(0.2)
  return lsmc_image.updateMask(low_qa).copyProperties(lsmc_image, ['system:time_start'])


'''
Add image timestamp to each image in time series
'''
def add_timestamp(image):
  timeImage = image.metadata('system:time_start').rename('timestamp')
  timeImageMasked = timeImage.updateMask(image.mask().select(0))
  return image.addBands(timeImageMasked)


'''
Perform linear interpolation on missing values
'''
def performInterpolation(image):
  image = ee.Image(image)
  beforeImages = ee.List(image.get('before'))
  beforeMosaic = ee.ImageCollection.fromImages(beforeImages).mosaic()
  afterImages = ee.List(image.get('after'))
  afterMosaic = ee.ImageCollection.fromImages(afterImages).mosaic()

  # Interpolation formula
  # y = y1 + (y2-y1)*((t – t1) / (t2 – t1))
  # y = interpolated image
  # y1 = before image
  # y2 = after image
  # t = interpolation timestamp
  # t1 = before image timestamp
  # t2 = after image timestamp

  t1 = beforeMosaic.select('timestamp').rename('t1')
  t2 = afterMosaic.select('timestamp').rename('t2')
  t = image.metadata('system:time_start').rename('t')
  timeImage = ee.Image.cat([t1, t2, t])
  timeRatio = timeImage.expression('(t - t1) / (t2 - t1)', {
                  't': timeImage.select('t'),
                  't1': timeImage.select('t1'),
                  't2': timeImage.select('t2'),
              })

  interpolated = beforeMosaic.add((afterMosaic.subtract(beforeMosaic).multiply(timeRatio)))
  result = image.unmask(interpolated)
  fill_value = ee.ImageCollection([beforeMosaic, afterMosaic]).mosaic()
  result = result.unmask(fill_value)

  return result.copyProperties(image, ['system:time_start'])


def interpolate_timeseries(S1_TS):
  lsmc_masked = S1_TS.map(mask_low_QA)
  filtered = lsmc_masked.map(add_timestamp)

  # Time window in which we are willing to look forward and backward for unmasked pixel in time series
  timeWindow = 120

  # Define a maxDifference filter to find all images within the specified days. Convert days to milliseconds.
  millis = ee.Number(timeWindow).multiply(1000*60*60*24)
  # Filter says that pick only those timestamps which lie between the 2 timestamps not more than millis difference apart
  maxDiffFilter = ee.Filter.maxDifference(
                              difference = millis,
                              leftField = 'system:time_start',
                              rightField = 'system:time_start',
                            )

  # Filter to find all images after a given image. Compare the image's timstamp against other images.
  # Images ahead of target image should have higher timestamp.
  lessEqFilter = ee.Filter.lessThanOrEquals(
                            leftField = 'system:time_start',
                            rightField = 'system:time_start'
                          )

  # Similarly define this filter to find all images before a given image
  greaterEqFilter = ee.Filter.greaterThanOrEquals(
                            leftField = 'system:time_start',
                            rightField = 'system:time_start'
                          )

  # Apply first join to find all images that are after the target image but within the timeWindow
  filter1 = ee.Filter.And( maxDiffFilter, lessEqFilter )
  join1 = ee.Join.saveAll(
                  matchesKey = 'after',
                  ordering = 'system:time_start',
                  ascending = False
          )
  join1Result = join1.apply(
                  primary = filtered,
                  secondary = filtered,
                  condition = filter1
                )

  # Apply first join to find all images that are after the target image but within the timeWindow
  filter2 = ee.Filter.And( maxDiffFilter, greaterEqFilter )
  join2 = ee.Join.saveAll(
                  matchesKey = 'before',
                  ordering = 'system:time_start',
                  ascending = True
          )
  join2Result = join2.apply(
                  primary = join1Result,
                  secondary = join1Result,
                  condition = filter2
                )

  interpolated_S1_TS = ee.ImageCollection(join2Result.map(performInterpolation))

  return interpolated_S1_TS


'''
Function Definition to get Padded NDVI LSMC timeseries image for a given ROI
'''
def Get_Padded_NDVI_TS_Image(startDate, endDate, roi_boundary):
  L7, L8, S2 = Get_L7_L8_S2_ImageCollections(startDate, endDate, roi_boundary)

  harmonized_LS_ic = Harmonize_L7_L8_S2(L7, L8, S2)
  harmonized_LS_ic = harmonized_LS_ic.map(addNDVI)
  LSC = Get_LS_16Day_NDVI_TimeSeries(startDate, endDate, harmonized_LS_ic)
  LSMC_NDVI = Combine_LS_Modis(LSC)
  Interpolated_LSMC_NDVI = interpolate_timeseries(LSMC_NDVI)
  final_LSMC_NDVI_TS = Interpolated_LSMC_NDVI.select(['gapfilled_NDVI_lsc']).toBands()
  final_LSMC_NDVI_TS = final_LSMC_NDVI_TS.clip(roi_boundary)

  input_bands = final_LSMC_NDVI_TS.bandNames()
  return final_LSMC_NDVI_TS, input_bands


'''
Function definition to compute euclidean distance to each cluster centroid
features ---> clusters
flattened ---> time series image clipped to target area
input_bands ---> band names for time series image
studyarea ---> geometry of region of interest
'''
# Function to get distances as required from each pixel to each cluster centroid
def Get_Euclidean_Distance(cluster_centroids, roi_timeseries_img, input_bands, roi_boundary):

  def wrapper(curr_centroid):
    temp_img = ee.Image()
    curr_centroid = ee.Feature(curr_centroid).setGeometry(roi_boundary)
    temp_fc = ee.FeatureCollection( [curr_centroid] )
    class_img = temp_fc.select(['class']).reduceToImage(['class'], ee.Reducer.first()).rename(['class'])
    def create_img(band_name):
      return temp_fc.select([band_name]).reduceToImage([band_name], ee.Reducer.first()).rename([band_name])

    temp_img = input_bands.map(create_img)
    empty = ee.Image()
    temp_img = ee.Image( temp_img.iterate( lambda img, prev: ee.Image(prev).addBands(img) , empty))

    temp_img = temp_img.select(temp_img.bandNames().remove('constant'))
    distance = roi_timeseries_img.spectralDistance(temp_img, 'sed')
    confidence = ee.Image(1.0).divide(distance).rename(['confidence'])
    distance = distance.addBands(confidence)
    return distance.addBands(class_img.rename(['class'])).set('class', curr_centroid.get('class'))

  return cluster_centroids.map(wrapper)


'''
Function definition to get final prediction image from distance images
'''
def Get_final_prediction_image(distance_imgs_list):
  # Denominator is an image that is sum of all confidences to each cluster
  sum_of_distances = ee.ImageCollection( distance_imgs_list ).select(['confidence']).sum().unmask()
  distance_imgs_ic = ee.ImageCollection( distance_imgs_list ).select(['distance','class'])

  # array is an image where distance band is an array of distances to each cluster centroid and class band is an array of classes associated with each cluster
  array_img = ee.ImageCollection(distance_imgs_ic).toArray()

  axes = {'image': 0, 'band':1}
  sort = array_img.arraySlice(axes['band'], 0, 1)
  sorted = array_img.arraySort(sort)

  # take the first image only
  values = sorted.arraySlice(axes['image'], 0, 1)
  # convert back to an image
  min = values.arrayProject([axes['band']]).arrayFlatten([['distance', 'class']])
  # Extract the hard classification
  predicted_class_img = min.select(1)
  predicted_class_img = predicted_class_img.rename(['predicted_label'])

  return predicted_class_img


def get_cropping_frequency(roi_boundary, startDate, endDate):
  cluster_centroids = ee.FeatureCollection('projects/ee-indiasat/assets/L3_LULC_Clusters/Final_Level3_PanIndia_Clusters')
  ignore_clusters = [12] # remove invalid clusters
  cluster_centroids = cluster_centroids.filter(ee.Filter.Not( ee.Filter.inList('class', ignore_clusters)))

  final_LSMC_NDVI_TS, input_bands =  Get_Padded_NDVI_TS_Image(startDate, endDate, roi_boundary)
  distance_imgs_list = Get_Euclidean_Distance(cluster_centroids, final_LSMC_NDVI_TS, input_bands, roi_boundary)
  final_classified_img = Get_final_prediction_image(distance_imgs_list)

  return final_classified_img
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Original Pan-India Cropland Time Series

# %%
croplands = ee.FeatureCollection('projects/proj76/assets/Begalavi_part_4')
roi_boundary = croplands.geometry()

startDate = '2022-04-01'
endDate = '2023-03-31'

L7, L8, S2 = Get_L7_L8_S2_ImageCollections(startDate, endDate, roi_boundary)

harmonized_LS_ic = Harmonize_L7_L8_S2(L7, L8, S2)
harmonized_LS_ic = harmonized_LS_ic.map(addNDVI)
LSC = Get_LS_16Day_NDVI_TimeSeries(startDate, endDate, harmonized_LS_ic)
LSMC_NDVI = Combine_LS_Modis(LSC)
Interpolated_LSMC_NDVI = interpolate_timeseries(LSMC_NDVI)
final_LSMC_NDVI_TS = Interpolated_LSMC_NDVI.select(['gapfilled_NDVI_lsc']).toBands()
final_LSMC_NDVI_TS = final_LSMC_NDVI_TS.clip(roi_boundary)

train_set = final_LSMC_NDVI_TS.sampleRegions(
  collection = croplands,
  scale = 30,
  geometries = False
)

task = ee.batch.Export.table.toDrive(
  collection = train_set,
  folder = 'Begalavi_15Day',
  description = 'GCVI_15Days',
  fileNamePrefix = 'Begalavi_15Days_part4',
  fileFormat = 'CSV',
  )

task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # AEZ-based Pan-India Cropland Time Series

# %%
for i in range(1,21):
  print("Running for AEZ ",i)
  agro_eco_regions = ee.FeatureCollection('users/mtpictd/agro_eco_regions')
  roi_boundary = agro_eco_regions.filter(ee.Filter.eq('ae_regcode', i)).geometry()

  startDate = '2021-04-01'
  endDate = '2021-09-30'

  L7, L8, S2 = Get_L7_L8_S2_ImageCollections(startDate, endDate, roi_boundary)

  harmonized_LS_ic = Harmonize_L7_L8_S2(L7, L8, S2)
  harmonized_LS_ic = harmonized_LS_ic.map(addNDVI)
  LSC = Get_LS_16Day_NDVI_TimeSeries(startDate, endDate, harmonized_LS_ic)
  LSMC_NDVI = Combine_LS_Modis(LSC)
  Interpolated_LSMC_NDVI = interpolate_timeseries(LSMC_NDVI)
  final_LSMC_NDVI_TS = Interpolated_LSMC_NDVI.select(['gapfilled_NDVI_lsc']).toBands()
  final_LSMC_NDVI_TS = final_LSMC_NDVI_TS.clip(roi_boundary)
  # pprint(final_LSMC_NDVI_TS.bandNames().getInfo())

  DW_Image = ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1') \
                .filterDate(startDate, endDate) \
                .filterBounds(roi_boundary) \
                .select('label') \
                .mode().clip(roi_boundary)

  crop_mask = DW_Image.select('label').eq(4)

  output_image = final_LSMC_NDVI_TS.updateMask(crop_mask)

  train_set_points = crop_mask.stratifiedSample(
    numPoints = 0,
    scale =  30,
    classBand = 'label',
    classValues = [1],
    classPoints = [5000],
    seed = 7,
    tileScale = 8,
    geometries = True,
    projection = 'EPSG:4326',
    region = roi_boundary
    )


  task = ee.batch.Export.table.toAsset(
    collection = train_set_points,
    description = 'Non_Padded_AEZ'+str(i)+'_TrainingPoints_5K',
    assetId = 'projects/ee-indiasat/assets/Rasterized_Groundtruth/Non_Padded_AEZ'+str(i)+'_TrainingPoints_5K',
    )
  task.start()


  train_set = output_image.sampleRegions(
    collection = train_set_points,
    scale = 30,
    tileScale = 8,
    geometries = False
  )

  task = ee.batch.Export.table.toDrive(
    collection = train_set,
    folder = 'Non_Padded_AEZs',
    description = 'Non_Padded_AEZ'+str(i)+'_NDVI_TS_5K',
    fileNamePrefix = 'Non_Padded_AEZ'+str(i)+'_NDVI_TS_5K',
    fileFormat = 'CSV',
    )

  task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Running for AEZ  1
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\ee\data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File ~\anaconda3\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://earthengine.googleapis.com/v1/projects/proj76/table:export?alt=json returned "Permission 'earthengine.assets.create' denied on resource 'projects/ee-indiasat' (or it may not exist).". Details: "Permission 'earthengine.assets.create' denied on resource 'projects/ee-indiasat' (or it may not exist).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[9], line 49
#      30 train_set_points = crop_mask.stratifiedSample(
#      31   numPoints = 0,
#      32   scale =  30,
#    (...)
#      40   region = roi_boundary
#      41   )
#      44 task = ee.batch.Export.table.toAsset(
#      45   collection = train_set_points,
#      46   description = 'Non_Padded_AEZ'+str(i)+'_TrainingPoints_5K',
#      47   assetId = 'projects/ee-indiasat/assets/Rasterized_Groundtruth/Non_Padded_AEZ'+str(i)+'_TrainingPoints_5K',
#      48   )
# ---> 49 task.start()
#      52 train_set = output_image.sampleRegions(
#      53   collection = train_set_points,
#      54   scale = 30,
#      55   tileScale = 8,
#      56   geometries = False
#      57 )
#      59 task = ee.batch.Export.table.toDrive(
#      60   collection = train_set,
#      61   folder = 'Non_Padded_AEZs',
#    (...)
#      64   fileFormat = 'CSV',
#      65   )
#
# File ~\anaconda3\Lib\site-packages\ee\batch.py:149, in Task.start(self)
#     147   result = data.exportMap(self._request_id, self.config)
#     148 elif self.task_type == Task.Type.EXPORT_TABLE:
# --> 149   result = data.exportTable(self._request_id, self.config)
#     150 elif self.task_type == Task.Type.EXPORT_VIDEO:
#     151   result = data.exportVideo(self._request_id, self.config)
#
# File ~\anaconda3\Lib\site-packages\ee\data.py:1767, in exportTable(request_id, params)
#    1746 """Starts a table export task running.
#    1747
#    1748 This is a low-level method. The higher-level ee.batch.Export.table object
#    (...)
#    1764   If you are using the cloud API, this will be an Operation.
#    1765 """
#    1766 params = params.copy()
# -> 1767 return _prepare_and_run_export(
#    1768     request_id, params, _get_cloud_projects().table().export
#    1769 )
#
# File ~\anaconda3\Lib\site-packages\ee\data.py:1884, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1881   params['expression'] = serializer.encode(
#    1882       params['expression'], for_cloud_api=True)
#    1883 num_retries = MAX_RETRIES if request_id else 0
# -> 1884 return _execute_cloud_call(
#    1885     export_endpoint(project=_get_projects_path(), body=params),
#    1886     num_retries=num_retries)
#
# File ~\anaconda3\Lib\site-packages\ee\data.py:404, in _execute_cloud_call(call, num_retries)
#     402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
# --> 404   raise _translate_cloud_exception(e)
#
# EEException: Permission 'earthengine.assets.create' denied on resource 'projects/ee-indiasat' (or it may not exist).

# %% [markdown]
# # AEZ-6 based Cropland Time Series

# %%
agro_eco_regions = ee.FeatureCollection('users/mtpictd/agro_eco_regions')
roi_boundary = agro_eco_regions.filter(ee.Filter.eq('ae_regcode', 6)).geometry()

startDate = '2021-04-01'
endDate = '2021-09-30'

L7, L8, S2 = Get_L7_L8_S2_ImageCollections(startDate, endDate, roi_boundary)

harmonized_LS_ic = Harmonize_L7_L8_S2(L7, L8, S2)
harmonized_LS_ic = harmonized_LS_ic.map(addNDVI)
LSC = Get_LS_16Day_NDVI_TimeSeries(startDate, endDate, harmonized_LS_ic)
LSMC_NDVI = Combine_LS_Modis(LSC)
Interpolated_LSMC_NDVI = interpolate_timeseries(LSMC_NDVI)
final_LSMC_NDVI_TS = Interpolated_LSMC_NDVI.select(['gapfilled_NDVI_lsc']).toBands()
final_LSMC_NDVI_TS = final_LSMC_NDVI_TS.clip(roi_boundary)
# pprint(final_LSMC_NDVI_TS.bandNames().getInfo())

DW_Image = ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1') \
              .filterDate(startDate, endDate) \
              .filterBounds(roi_boundary) \
              .select('label') \
              .mode().clip(roi_boundary)

crop_mask = DW_Image.select('label').eq(4)

output_image = final_LSMC_NDVI_TS.updateMask(crop_mask)

train_set_points = crop_mask.stratifiedSample(
  numPoints = 0,
  scale =  30,
  classBand = 'label',
  classValues = [1],
  classPoints = [40000],
  seed = 7,
  tileScale = 8,
  geometries = True,
  projection = 'EPSG:4326',
  region = roi_boundary
  )


task = ee.batch.Export.table.toAsset(
  collection = train_set_points,
  description = 'Non_Padded_AEZ6_TrainingPoints_40K',
  assetId = 'projects/ee-indiasat/assets/Rasterized_Groundtruth/Non_Padded_AEZ6_TrainingPoints_40K',
  )
task.start()


train_set = output_image.sampleRegions(
  collection = train_set_points,
  scale = 30,
  tileScale = 8,
  geometries = False
)

task = ee.batch.Export.table.toDrive(
  collection = train_set,
  folder = 'Non_Padded_AEZ6',
  description = 'Non_Padded_AEZ6_NDVI_TS',
  fileNamePrefix = 'Non_Padded_AEZ6_NDVI_TS',
  fileFormat = 'CSV',
  )

task.start()

# %% [markdown]
# # Raichur-level Cropland Time Series
#
# 100K throws error of computed value too large.

# %%
districts = ee.FeatureCollection('projects/ee-mtpictd/assets/india_district_boundaries')
roi_boundary = districts.filter(ee.Filter.eq('Name', 'Raichur')).geometry()

startDate = '2021-04-01'
endDate = '2021-09-30'

L7, L8, S2 = Get_L7_L8_S2_ImageCollections(startDate, endDate, roi_boundary)

harmonized_LS_ic = Harmonize_L7_L8_S2(L7, L8, S2)
harmonized_LS_ic = harmonized_LS_ic.map(addNDVI)
LSC = Get_LS_16Day_NDVI_TimeSeries(startDate, endDate, harmonized_LS_ic)
LSMC_NDVI = Combine_LS_Modis(LSC)
Interpolated_LSMC_NDVI = interpolate_timeseries(LSMC_NDVI)
final_LSMC_NDVI_TS = Interpolated_LSMC_NDVI.select(['gapfilled_NDVI_lsc']).toBands()
final_LSMC_NDVI_TS = final_LSMC_NDVI_TS.clip(roi_boundary)
# pprint(final_LSMC_NDVI_TS.bandNames().getInfo())

DW_Image = ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1') \
              .filterDate(startDate, endDate) \
              .filterBounds(roi_boundary) \
              .select('label') \
              .mode().clip(roi_boundary)

crop_mask = DW_Image.select('label').eq(4)

output_image = final_LSMC_NDVI_TS.updateMask(crop_mask)

train_set_points = crop_mask.stratifiedSample(
  numPoints = 0,
  scale =  30,
  classBand = 'label',
  classValues = [1],
  classPoints = [50000],
  seed = 7,
  tileScale = 16,
  geometries = True,
  projection = 'EPSG:4326',
  region = roi_boundary
  )


task = ee.batch.Export.table.toAsset(
  collection = train_set_points,
  description = 'Non_Padded_Raichur_TrainingPoints_50K_Tilescale16',
  assetId = 'projects/ee-indiasat/assets/Rasterized_Groundtruth/Non_Padded_Raichur_TrainingPoints_50K_Tilescale16',
  )
task.start()


train_set = output_image.sampleRegions(
  collection = train_set_points,
  scale = 30,
  tileScale = 16,
  geometries = False
)

task = ee.batch.Export.table.toDrive(
  collection = train_set,
  folder = 'Non_Padded_Raichur',
  description = 'Non_Padded_Raichur_NDVI_TS_50K_Tilescale16',
  fileNamePrefix = 'Non_Padded_Raichur_NDVI_TS_50K_Tilescale16',
  fileFormat = 'CSV',
  )

task.start()

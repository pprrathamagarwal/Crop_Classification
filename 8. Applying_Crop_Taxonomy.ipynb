# %%
import pandas as pd

# %%
# Reload crop_mapping and original DataFrame since the environment was reset
# Load original CSV
input_file='Karnataka_Datasets/Across/Kharif/Cropland_Masked/Cropland_Mask_2021_22/AEZ_6/dharwad_merged.csv'
df = pd.read_csv(input_file)

# Re-declare crop_mapping
crop_mapping = {
    'Bajra': ('Short', 'Low', 'Grass'),
    'Banana': ('Tall', 'Long', 'Tree'),
    'Coconut': ('Tall', 'Long', 'Tree'),
    'Jowar': ('Medium', 'Low', 'Grass'),
    'Maize': ('Medium', 'Medium', 'Grass'),
    'Paddy': ('Short', 'Medium', 'Grass'),
    'Potato': ('Short', 'Medium', 'Root'),
    'Ragi': ('Short', 'Low', 'Grass'),
    'Redgram': ('Medium', 'Medium', 'Shrub'),
    'Wheat': ('Short', 'Low', 'Grass'),
    'Eucalyptus': ('Tall', 'Long', 'Tree'),
    'Rose': ('Short', 'Medium', 'Shrub'),
    'HariMirch': ('Short', 'Low', 'Shrub'),
    'Eknayaka': ('Short', 'Medium', 'Shrub'),
    'Chow Chow': ('Medium', 'Medium', 'Shrub'),
    'Beans': ('Short', 'Low', 'Shrub'),
    'Ridgegourd': ('Medium', 'Medium', 'Vine'),
    'Bottlegourd': ('Medium', 'Medium', 'Vine'),
    'Marigold': ('Short', 'Medium', 'Shrub'),
    'Gerbera': ('Short', 'Medium', 'Shrub'),
    'Chrysanthemum': ('Short', 'Medium', 'Shrub'),
    'Tomato': ('Short', 'Medium', 'Shrub'),
    'Horsegram': ('Medium', 'Medium', 'Shrub'),
    'Avare': ('Medium', 'Medium', 'Shrub'),
    'Coriander': ('Short', 'Low', 'Shrub'),
    'Silver Oak': ('Tall', 'Long', 'Tree'),
    'Neem': ('Tall', 'Long', 'Tree'),
    'Guava': ('Medium', 'Long', 'Tree'),
    'Dahlia': ('Short', 'Medium', 'Shrub'),
    'Trees': ('Tall', 'Long', 'Tree'),
    'Elephantfoot_Yam': ('Medium', 'Long', 'Root'),
    'Malabar Neem': ('Tall', 'Long', 'Tree'),
    'Sweetcorn': ('Medium', 'Medium', 'Grass'),
    'Cucumber': ('Medium', 'Medium', 'Vine'),
    'Carrot': ('Short', 'Medium', 'Root'),
    'Mangoes': ('Tall', 'Long', 'Tree'),
    'Makkachari': ('Medium', 'Medium', 'Grass'),
    'Flower': ('Short', 'Medium', 'Shrub'),
    'Cabbage': ('Short', 'Medium', 'Shrub'),
    'Asparagus': ('Short', 'Medium', 'Shrub'),
    'Teak': ('Tall', 'Long', 'Tree'),
    'Drumstick': ('Medium', 'Long', 'Tree'),
    'Vegetables': ('Short', 'Medium', 'Shrub'),
    'Beetroot': ('Short', 'Medium', 'Root'),
    'Cauliflower': ('Short', 'Medium', 'Shrub'),
    'Mint': ('Short', 'Low', 'Shrub'),
    'Methi Leaves': ('Short', 'Low', 'Shrub'),
    'Dill': ('Short', 'Low', 'Shrub'),
    'Noni': ('Medium', 'Long', 'Tree'),
    'Ivygourd': ('Medium', 'Medium', 'Vine'),
    'Brinjal': ('Short', 'Medium', 'Shrub'),
    'Green Fodder': ('Medium', 'Medium', 'Grass'),
    'Acacia': ('Tall', 'Long', 'Tree'),
    'Arecanut': ('Tall', 'Long', 'Tree'),
    'Papaya': ('Tall', 'Long', 'Tree'),
    'Chiku': ('Tall', 'Long', 'Tree'),
    'Fruits': ('Medium', 'Long', 'Tree'),
    'Spinach': ('Short', 'Low', 'Shrub'),
    'Grapes': ('Medium', 'Long', 'Vine'),
    'Fennel': ('Short', 'Low', 'Shrub'),
    'Capsicum': ('Short', 'Medium', 'Shrub'),
    'Bittergourd': ('Medium', 'Medium', 'Vine'),
    'Mulberry': ('Tall', 'Long', 'Tree'),
    'Knolkhol': ('Short', 'Medium', 'Shrub'),
    'Crossandra': ('Short', 'Medium', 'Shrub'),
    'Agaves': ('Tall', 'Long', 'Shrub'),
    'Gladiolus': ('Short', 'Medium', 'Shrub'),
    'BlackPepper': ('Tall', 'Long', 'Vine'),
    'Groundnut': ('Short', 'Long', 'Shrub'),
    'Barley': ('Short', 'Low', 'Grass'),
    'Tuberose': ('Short', 'Medium', 'Shrub'),
    'Lemon': ('Medium', 'Long', 'Tree'),
    'Sugarcane': ('Tall', 'Long', 'Grass'),
    'Peas': ('Short', 'Medium', 'Shrub'),
    'Indigo': ('Medium', 'Medium', 'Shrub'),
    'China Aster': ('Short', 'Medium', 'Shrub'),
    'LadyFinger': ('Short', 'Medium', 'Shrub'),
    'Vegetable Cowpea': ('Short', 'Low', 'Shrub'),
    'Harimirch': ('Short', 'Low', 'Shrub'),
    'Dhavana': ('Short', 'Low', 'Shrub'),
    'Tamarind': ('Tall', 'Long', 'Tree'),
    'Turmeric': ('Short', 'Long', 'Root'),
    'Cowpea': ('Short', 'Low', 'Shrub'),
    'Dolichuous_Bean': ('Medium', 'Medium', 'Shrub'),
    'Pumpkin': ('Medium', 'Medium', 'Vine'),
    'Broccoli': ('Short', 'Medium', 'Shrub'),
    'Sunflower': ('Medium', 'Medium', 'Shrub'),
    'Sweet Corn': ('Medium', 'Medium', 'Grass'),
    'Rose Wood': ('Tall', 'Long', 'Tree'),
    'Baby Corn': ('Medium', 'Low', 'Grass'),
    'Ginger': ('Short', 'Long', 'Root'),
    'Sweet Potato': ('Short', 'Long', 'Root'),
    'Shimp Nut': ('Medium', 'Medium', 'Shrub'),
    'Snakegourd': ('Medium', 'Medium', 'Vine'),
    'Pomegranate': ('Medium', 'Long', 'Tree'),
    'Jamun': ('Tall', 'Long', 'Tree'),
    'Greengram': ('Short', 'Low', 'Shrub'),
    'Cashewnuts': ('Tall', 'Long', 'Tree'),
    'Saffron': ('Short', 'Low', 'Shrub'),
    'Chive': ('Short', 'Low', 'Shrub'),
    'Mahagani Tree': ('Tall', 'Long', 'Tree'),
    'Casuarina Tree': ('Tall', 'Long', 'Tree'),
    'Bluegrapes': ('Medium', 'Long', 'Vine'),
    'Jasmine Pubescens': ('Short', 'Medium', 'Shrub'),
    'Gram': ('Short', 'Low', 'Shrub'),
    'Grapes Seedless': ('Medium', 'Long', 'Vine'),
    'Ashgourd': ('Medium', 'Medium', 'Vine'),
    'Nigerseed': ('Short', 'Low', 'Shrub'),
    'Jackfruit': ('Tall', 'Long', 'Tree'),
    'Sandalwood': ('Tall', 'Long', 'Tree'),
    'Linseed': ('Short', 'Low', 'Shrub'),
    'Curry Leaves': ('Short', 'Low', 'Shrub'),
    'Lentil': ('Short', 'Medium', 'Shrub'),
    'Rice': ('Short', 'Medium', 'Grass'),
    'Green pea': ('Short', 'Medium', 'Shrub'),
    'Bersem': ('Short', 'Medium', 'Grass'),
}

# Apply herb corrections
fixes = {
'Cotton': ('Medium', 'Long', 'Shrub'),
'Gram': ('Short', 'Low', 'Herb'),  # Already correct
'Green Chillies': ('Short', 'Low', 'Shrub'),
'Red Chillies': ('Short', 'Low', 'Shrub'),
'Greengram': ('Short', 'Low', 'Shrub'),
'Groundnut': ('Short', 'Long', 'Shrub'),
'Jowar': ('Medium', 'Low', 'Grass'),
'Maize': ('Medium', 'Medium', 'Grass'),
'Mangoes': ('Tall', 'Long', 'Tree'),
'Onion': ('Short', 'Medium', 'Root'),
'Paddy': ('Short', 'Medium', 'Grass'),
'Potato': ('Short', 'Medium', 'Root'),
'Soyabean': ('Medium', 'Medium', 'Shrub'),
'Sugarcane': ('Tall', 'Long', 'Grass'),
'Urad': ('Short', 'Low', 'Shrub'),
'Wheat': ('Short', 'Low', 'Grass'),
'Turmeric': ('Short', 'Long', 'Root'),
'Castor': ('Tall', 'Long', 'Shrub'),
'Chrysanthemum': ('Short', 'Medium', 'Shrub'),
'Green Peas': ('Short', 'Medium', 'Shrub'),
'Grapes': ('Medium', 'Long', 'Vine'),
'Mosambi':('Tall', 'Long', 'Tree'),
'Ladyfinger':('Short', 'Medium', 'Shrub')

}

# Update main crop mapping
crop_mapping.update(fixes)

# Mappings
height_mapping = {'Short': 1, 'Medium': 2, 'Tall': 3}
duration_mapping = {'Low': 1, 'Medium': 2, 'Long': 3}
structure_mapping = {'Tree': 1, 'Shrub': 2, 'Grass': 3, 'Root': 4, 'Vine': 5, 'Herb': 6}

# Apply taxonomy
df[['Height', 'Duration', 'Structure']] = df['Crop_Name'].map(crop_mapping).apply(pd.Series)
df['height_numeric'] = df['Height'].map(height_mapping)
df['duration_numeric'] = df['Duration'].map(duration_mapping)
df['structure_numeric'] = df['Structure'].map(structure_mapping)

# Save final CSV
df.to_csv(input_file, index=False)

# %% [markdown]
# # Elbow Plot

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Load the interpolated CSV
df = pd.read_csv("Karnataka_Datasets/Across/S2/Merged_Karnataka_S2_Kharif_Interpolated.csv")

# Identify GCVI columns (e.g., GCVI_1 to GCVI_37)
gcvi_columns = sorted([col for col in df.columns if re.match(r'GCVI_\d+$', col)],
                      key=lambda x: int(x.split('_')[1]))

# Group by Crop_Name
crop_groups = df.groupby('Crop_Name')

for crop, group in crop_groups:
    # Extract only the GCVI columns
    gcvi_data = group[gcvi_columns]
    
    # Scale the data (optional but recommended for clustering)
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(gcvi_data)

    # Compute distortions for different K values
    distortions = []
    K = range(1, 11)
    
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
        kmeans.fit(data_scaled)
        distortions.append(kmeans.inertia_)

    # Plot the elbow curve
    plt.figure()
    plt.plot(K, distortions, 'bo-')
    plt.title(f'Elbow Method for Crop: {crop}')
    plt.xlabel('Number of Clusters (K)')
    plt.ylabel('Distortion (Inertia)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=6.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# # K Means Clustering

# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib.pyplot as plt
from tslearn.clustering import TimeSeriesKMeans
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from sklearn.metrics import pairwise_distances_argmin_min

# Load data
df = pd.read_csv("Karnataka_Datasets/Across/S2/Merged_Karnataka_S2_Kharif_Interpolated.csv")

# Extract GCVI time series columns
gcvi_columns = sorted([col for col in df.columns if re.match(r'GCVI_\d+$', col)],
                      key=lambda x: int(x.split('_')[1]))

# Define number of clusters per crop
k_per_crop = {
    'Arecanut': 8,
    'Avare': 6,
    'Bajra': 4,
    'Banana': 4,
    'Black Pepper': 4,
    'Coconut': 6,
    'Grapes': 6,
    'Guava': 6,
    'Jowar': 6,
    'Lemon': 5,
    'Maize': 6,
    'Mangoes': 6,
    'Onion': 5,
    'Paddy': 6,
    'Potato': 6,
    'Ragi': 7,
    'Redgram': 6,
    'Rose': 6,
    'Sapota': 6,
    'Sugarcane': 4
    
    
    # Add more if needed
}

# Output dirs
os.makedirs("Karnataka_Datasets/Across/S2/clustered_crops", exist_ok=True)
os.makedirs("Karnataka_Datasets/Across/S2/cluster_plots", exist_ok=True)

# Group by crop
crop_groups = df.groupby("Crop_Name")

for crop, group in crop_groups:
    if crop not in k_per_crop:
        continue

    print(f"Processing crop: {crop}")
    k = k_per_crop[crop]
    group_clean = group.dropna(subset=gcvi_columns).copy()

    if group_clean.empty:
        print(f"Skipping {crop} due to no clean data.")
        continue

    # Prepare time series data
    ts_data = group_clean[gcvi_columns].to_numpy()
    ts_scaled = TimeSeriesScalerMeanVariance().fit_transform(ts_data)

    # TimeSeries KMeans
    model = TimeSeriesKMeans(n_clusters=k, metric="dtw", random_state=42)
    labels = model.fit_predict(ts_scaled)

    # Closest to centroid
    closest_indices, _ = pairwise_distances_argmin_min(model.cluster_centers_.reshape(k, -1),
                                                        ts_scaled.reshape(len(ts_scaled), -1))

    # Add clustering info
    group_clean["Cluster"] = labels
    group_clean["IsCentroid"] = False
    for idx in closest_indices:
        group_clean.iloc[idx, group_clean.columns.get_loc("IsCentroid")] = True

    # Save cluster CSV
    csv_path = f"Karnataka_Datasets/Across/S2/clustered_crops/{crop}_clusters.csv"
    group_clean.to_csv(csv_path, index=False)
    print(f"Saved CSV for {crop}: {csv_path}")

    # --- Visualization ---
    plt.figure(figsize=(3 * k, 5))
    for cluster_id in range(k):
        plt.subplot(1, k, cluster_id + 1)

        cluster_series = ts_scaled[labels == cluster_id]

        for ts in cluster_series[:10]:  # plot up to 10
            plt.plot(ts.ravel(), color="gray", alpha=0.4)

        plt.plot(model.cluster_centers_[cluster_id].ravel(), color="red", linewidth=2, label="Centroid")
        plt.title(f"{crop} - Cluster {cluster_id + 1}")
        plt.ylim(np.nanmin(ts_scaled), np.nanmax(ts_scaled))
        plt.grid(True)
        plt.tight_layout()

    plt.suptitle(f"GCVI Clustering for {crop} (K={k})", fontsize=14)
    plot_path = f"Karnataka_Datasets/Across/S2/cluster_plots/{crop}_clusters.png"
    plt.savefig(plot_path)
    plt.show()
    print(f"Saved plot for {crop}: {plot_path}")
# Out:
# Processing crop: Arecanut
# Saved CSV for Arecanut: Karnataka_Datasets/Across/S2/clustered_crops/Arecanut_clusters.csv
# Saved plot for Arecanut: Karnataka_Datasets/Across/S2/cluster_plots/Arecanut_clusters.png
# Processing crop: Avare
# Saved CSV for Avare: Karnataka_Datasets/Across/S2/clustered_crops/Avare_clusters.csv
# Saved plot for Avare: Karnataka_Datasets/Across/S2/cluster_plots/Avare_clusters.png
# Processing crop: Bajra
# Saved CSV for Bajra: Karnataka_Datasets/Across/S2/clustered_crops/Bajra_clusters.csv
# Saved plot for Bajra: Karnataka_Datasets/Across/S2/cluster_plots/Bajra_clusters.png
# Processing crop: Banana
# Saved CSV for Banana: Karnataka_Datasets/Across/S2/clustered_crops/Banana_clusters.csv
# Saved plot for Banana: Karnataka_Datasets/Across/S2/cluster_plots/Banana_clusters.png
# Processing crop: Black Pepper
# Saved CSV for Black Pepper: Karnataka_Datasets/Across/S2/clustered_crops/Black Pepper_clusters.csv
# Saved plot for Black Pepper: Karnataka_Datasets/Across/S2/cluster_plots/Black Pepper_clusters.png
# Processing crop: Coconut
# Saved CSV for Coconut: Karnataka_Datasets/Across/S2/clustered_crops/Coconut_clusters.csv
# Saved plot for Coconut: Karnataka_Datasets/Across/S2/cluster_plots/Coconut_clusters.png
# Processing crop: Grapes
# Saved CSV for Grapes: Karnataka_Datasets/Across/S2/clustered_crops/Grapes_clusters.csv
# Saved plot for Grapes: Karnataka_Datasets/Across/S2/cluster_plots/Grapes_clusters.png
# Processing crop: Guava
# Saved CSV for Guava: Karnataka_Datasets/Across/S2/clustered_crops/Guava_clusters.csv
# Saved plot for Guava: Karnataka_Datasets/Across/S2/cluster_plots/Guava_clusters.png
# Processing crop: Jowar
# Saved CSV for Jowar: Karnataka_Datasets/Across/S2/clustered_crops/Jowar_clusters.csv
# Saved plot for Jowar: Karnataka_Datasets/Across/S2/cluster_plots/Jowar_clusters.png
# Processing crop: Lemon
# Saved CSV for Lemon: Karnataka_Datasets/Across/S2/clustered_crops/Lemon_clusters.csv
# Saved plot for Lemon: Karnataka_Datasets/Across/S2/cluster_plots/Lemon_clusters.png
# Processing crop: Maize
# Saved CSV for Maize: Karnataka_Datasets/Across/S2/clustered_crops/Maize_clusters.csv
# Saved plot for Maize: Karnataka_Datasets/Across/S2/cluster_plots/Maize_clusters.png
# Processing crop: Mangoes
# Saved CSV for Mangoes: Karnataka_Datasets/Across/S2/clustered_crops/Mangoes_clusters.csv
# Saved plot for Mangoes: Karnataka_Datasets/Across/S2/cluster_plots/Mangoes_clusters.png
# Processing crop: Onion
# Saved CSV for Onion: Karnataka_Datasets/Across/S2/clustered_crops/Onion_clusters.csv
# Saved plot for Onion: Karnataka_Datasets/Across/S2/cluster_plots/Onion_clusters.png
# Processing crop: Paddy
# Saved CSV for Paddy: Karnataka_Datasets/Across/S2/clustered_crops/Paddy_clusters.csv
# Saved plot for Paddy: Karnataka_Datasets/Across/S2/cluster_plots/Paddy_clusters.png
# Processing crop: Potato
# Saved CSV for Potato: Karnataka_Datasets/Across/S2/clustered_crops/Potato_clusters.csv
# Saved plot for Potato: Karnataka_Datasets/Across/S2/cluster_plots/Potato_clusters.png
# Processing crop: Ragi
# Saved CSV for Ragi: Karnataka_Datasets/Across/S2/clustered_crops/Ragi_clusters.csv
# Saved plot for Ragi: Karnataka_Datasets/Across/S2/cluster_plots/Ragi_clusters.png
# Processing crop: Redgram
# Saved CSV for Redgram: Karnataka_Datasets/Across/S2/clustered_crops/Redgram_clusters.csv
# Saved plot for Redgram: Karnataka_Datasets/Across/S2/cluster_plots/Redgram_clusters.png
# Processing crop: Rose
# Saved CSV for Rose: Karnataka_Datasets/Across/S2/clustered_crops/Rose_clusters.csv
# Saved plot for Rose: Karnataka_Datasets/Across/S2/cluster_plots/Rose_clusters.png
# Processing crop: Sapota
# Saved CSV for Sapota: Karnataka_Datasets/Across/S2/clustered_crops/Sapota_clusters.csv
# Saved plot for Sapota: Karnataka_Datasets/Across/S2/cluster_plots/Sapota_clusters.png
# Processing crop: Sugarcane
# Saved CSV for Sugarcane: Karnataka_Datasets/Across/S2/clustered_crops/Sugarcane_clusters.csv
# Saved plot for Sugarcane: Karnataka_Datasets/Across/S2/cluster_plots/Sugarcane_clusters.png

# %% [markdown]
# # Computing Distances

# %%
import pandas as pd
import numpy as np
import os
import re

# Directories
input_dir = "Karnataka_Datasets/Across/S2/clustered_crops/Fix/"
output_dir = "Karnataka_Datasets/Across/S2/clustered_crops_with_distance"
os.makedirs(output_dir, exist_ok=True)

# Process all CSV files in the input directory
for filename in os.listdir(input_dir):
    if not filename.endswith(".csv"):
        continue

    input_path = os.path.join(input_dir, filename)
    output_path = os.path.join(output_dir, filename)

    print(f"Processing: {filename}")
    df = pd.read_csv(input_path)

    # Extract GCVI columns and sort them
    gcvi_columns = sorted(
        [col for col in df.columns if re.match(r'GCVI_\d+$', col)],
        key=lambda x: int(x.split('_')[1])
    )

    if "Cluster" not in df.columns:
        print(f"Skipping {filename}: 'Cluster' column missing.")
        continue

    # Ensure Distance column exists
    df["Distance"] = np.nan

    # Loop through each cluster
    for cluster_id in sorted(df["Cluster"].unique()):
        cluster_data = df[df["Cluster"] == cluster_id]

        # Skip if cluster is empty or only has one point
        if cluster_data.shape[0] <= 1:
            print(f"Skipping cluster {cluster_id} in {filename}: not enough points.")
            continue

        # Determine centroid
        if "IsCentroid" in df.columns and any(cluster_data["IsCentroid"] == True):
            centroid_vector = cluster_data[cluster_data["IsCentroid"] == True].iloc[0][gcvi_columns].to_numpy()
            print(f"Cluster {cluster_id} in {filename}: Used marked centroid.")
        else:
            centroid_vector = cluster_data[gcvi_columns].median().to_numpy()
            print(f"Cluster {cluster_id} in {filename}: Computed centroid manually.")

        # Compute distances for this cluster
        for idx in cluster_data.index:
            ts_vector = df.loc[idx, gcvi_columns].to_numpy()
            distance = np.linalg.norm(ts_vector - centroid_vector)
            df.at[idx, "Distance"] = distance

    # Save the modified file
    df.to_csv(output_path, index=False)
    print(f"Saved: {output_path}\n")
# Out:
# Processing: Grapes_clusters.csv
# Cluster 0 in Grapes_clusters.csv: Used marked centroid.
# Cluster 1 in Grapes_clusters.csv: Computed centroid manually.
# Cluster 2 in Grapes_clusters.csv: Used marked centroid.
# Cluster 3 in Grapes_clusters.csv: Used marked centroid.
# Cluster 4 in Grapes_clusters.csv: Used marked centroid.
# Cluster 5 in Grapes_clusters.csv: Used marked centroid.
# Saved: Karnataka_Datasets/Across/S2/clustered_crops_with_distance\Grapes_clusters.csv
#
# Processing: Potato_clusters.csv
# Cluster 0 in Potato_clusters.csv: Used marked centroid.
# Cluster 1 in Potato_clusters.csv: Computed centroid manually.
# Cluster 2 in Potato_clusters.csv: Used marked centroid.
# Cluster 3 in Potato_clusters.csv: Used marked centroid.
# Cluster 4 in Potato_clusters.csv: Used marked centroid.
# Cluster 5 in Potato_clusters.csv: Used marked centroid.
# Saved: Karnataka_Datasets/Across/S2/clustered_crops_with_distance\Potato_clusters.csv

# %% [markdown]
# # Outlier Removing

# %%
# import pandas as pd
import numpy as np
import os

# Input directory with distances
input_dir = "Karnataka_Datasets/Across/S2/clustered_crops_with_distance"

# Output directories
outlier_dir = "Karnataka_Datasets/Across/S2/clustered_crops_outliers"
filtered_dir = "Karnataka_Datasets/Across/S2/clustered_crops_filtered"

os.makedirs(outlier_dir, exist_ok=True)
os.makedirs(filtered_dir, exist_ok=True)

for filename in os.listdir(input_dir):
    if not filename.endswith(".csv"):
        continue

    print(f"Processing: {filename}")
    input_path = os.path.join(input_dir, filename)
    df = pd.read_csv(input_path)

    if "Cluster" not in df.columns or "Distance" not in df.columns:
        print(f"Skipping {filename}: Missing 'Cluster' or 'Distance' column.")
        continue

    # DataFrames to collect final results
    all_outliers = []
    all_filtered = []

    for cluster_id in sorted(df["Cluster"].unique()):
        cluster_data = df[df["Cluster"] == cluster_id]

        if cluster_data.shape[0] < 4:
            # Skip small clusters
            all_filtered.append(cluster_data)
            continue

        q75 = cluster_data["Distance"].quantile(0.75)

        outliers = cluster_data[cluster_data["Distance"] > q75]
        remaining = cluster_data[cluster_data["Distance"] <= q75]

        all_outliers.append(outliers)
        all_filtered.append(remaining)

    # Concatenate and save
    outlier_df = pd.concat(all_outliers, ignore_index=True)
    filtered_df = pd.concat(all_filtered, ignore_index=True)

    outlier_df.to_csv(os.path.join(outlier_dir, filename), index=False)
    filtered_df.to_csv(os.path.join(filtered_dir, filename), index=False)

    print(f"Saved outliers → {os.path.join(outlier_dir, filename)}")
    print(f"Saved filtered → {os.path.join(filtered_dir, filename)}\n")

# %% [markdown]
# # Removing Duplicates

# %%
import pandas as pd
import re

# Load your CSV
df = pd.read_csv("Karnataka_Datasets/Across/S2/Merged_Karnataka_S2_Kharif_Mapped.csv")

# Group VI columns by base name (e.g., NDVI, GCVI)
vi_groups = {}
for col in df.columns:
    match = re.match(r"([A-Z]+VI)_\d+", col)
    if match:
        base = match.group(1)
        vi_groups.setdefault(base, []).append(col)

# Keep track of all rows to keep
mask = pd.Series([True] * len(df))

# For each VI group, remove duplicate rows within that group
for group_cols in vi_groups.values():
    group_dupes = df.duplicated(subset=group_cols)
    mask &= ~group_dupes  # Only keep the first occurrence of duplicates

# Filter the DataFrame
deduplicated_df = df[mask].reset_index(drop=True)

# Count how many rows were dropped
num_dropped = len(df) - len(deduplicated_df)
print(f"Rows dropped due to VI duplicates: {num_dropped}")
# Save the cleaned data if needed
deduplicated_df.to_csv("Karnataka_Datasets/Across/S2/Merged_Karnataka_S2_Kharif_Mapped_Clean.csv", index=False)
# Out:
# Rows dropped due to VI duplicates: 459

# %% [markdown]
# # Creating Final CSV(S2 Data only)

# %%
# import pandas as pd
import os

# Directory containing your CSV files
input_dir = "Karnataka_Datasets/Across/S2/clustered_crops_filtered"  # <-- update if needed
output_file = os.path.join(input_dir, "Karnataka_Kharif_S2_Data.csv")

# List to hold all DataFrames
df_list = []

for filename in os.listdir(input_dir):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_dir, filename)
        print(f"Reading: {filename}")
        df = pd.read_csv(file_path)
        df_list.append(df)

# Merge all
merged_df = pd.concat(df_list, ignore_index=True)

# Save to a single file
merged_df.to_csv(output_file, index=False)
print(f"\n✅ Merged CSV saved as: {output_file}")

# %% [markdown]
# # Train-Test Split

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the CSV file into a pandas DataFrame
file_path = 'Karnataka_Datasets/Across/Merged_Karnataka_S2_Kharif_Mapped_Clean.csv'  # replace with your actual file path
df = pd.read_csv(file_path)

# Perform the stratified split based on 'Crop_Name'
train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['Crop_Name'])

# Save the train and test DataFrames to new CSV files
train_filename = file_path.replace('.csv', '_train.csv')
test_filename = file_path.replace('.csv', '_test.csv')

train_df.to_csv(train_filename, index=False)
test_df.to_csv(test_filename, index=False)

print(f"Train file saved as: {train_filename}")
print(f"Test file saved as: {test_filename}")
# Out:
# Train file saved as: Karnataka_Datasets/Across/Merged_Karnataka_S2_Kharif_Mapped_Clean_train.csv
# Test file saved as: Karnataka_Datasets/Across/Merged_Karnataka_S2_Kharif_Mapped_Clean_test.csv

# %% [markdown]
# # Structure Counts

# %%
# Count unique values in the 'Structure' column
structure_counts = df['Structure'].value_counts()

# Print the counts
print(structure_counts)
# Out:
# Structure
# Grass Crop        52634
# Tree              19667
# Shrub             11395
# Root/Bulb Crop      135
# Name: count, dtype: int64
